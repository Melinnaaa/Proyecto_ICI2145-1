# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon-data.csv', sep=';')

# %%
df
# Out:
#                  Name                 Types  \
# 0           Abomasnow      ['Grass', 'Ice']
# 1      Abomasnow-Mega      ['Grass', 'Ice']
# 2                Abra           ['Psychic']
# 3               Absol              ['Dark']
# 4          Absol-Mega              ['Dark']
# ..                ...                   ...
# 913             Zubat  ['Flying', 'Poison']
# 914          Zweilous    ['Dark', 'Dragon']
# 915           Zygarde  ['Dragon', 'Ground']
# 916       Zygarde-10%  ['Dragon', 'Ground']
# 917  Zygarde-Complete  ['Dragon', 'Ground']
#
#                                          Abilities  Tier   HP  Attack  \
# 0                   ['Snow Warning', 'Soundproof']    PU   90      92
# 1                                 ['Snow Warning']  NUBL   90     132
# 2    ['Inner Focus', 'Magic Guard', 'Synchronize']    LC   25      20
# 3          ['Justified', 'Pressure', 'Super Luck']    PU   65     130
# 4                                 ['Magic Bounce']  RUBL   65     150
# ...

# %%
export = df[['Name', 'Types', 'HP']]

# %%
export.to_csv(path_or_buf = "out.csv")
